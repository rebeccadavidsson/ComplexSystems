# %% [markdown]
# # One Factor At a Time analysis

# %% [markdown]
# This notebook contains the code for an OFAT analysis. For each parameter and output variable a plot will be created.

# %%
# Import dependencies
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plot

# %% [markdown]
# ## Reading data

# %% [markdown]
# For each parameter there is a seperate file containing the data of varying that parameter while keeping the other parameters fixed at the default values. This function reads the data belonging to a parameter and returns it as a Pandas dataframe.

# %%
def read_data(path):
    data = pd.read_csv(path)
    data['total'] = np.round(data['N'] // 2) + np.round((data['N'] // 2) * data['ratio']) + data['N'] - np.round(
        data['N'] // 2) - np.round(
        (data['N'] // 2) * data['ratio'])

    data['pfl_net'] = (data['pheromone'] - data['followers'] - data['leaders']) / data['total']
    data['pu_net'] = (data['pheromone'] - data['unassigned']) / data['total']
    data['flu_net'] = (data['followers'] + data['leaders'] - data['unassigned']) / data['total']

    return data

# %% [markdown]
# ## Creating plots

# %% [markdown]
# In the module 'plot' the function 'plot_all_vars' is defined. This produces a parameter vs. output variable plot for each of the output variables. The resulting figure contains a scatter plot and a line plot of the mean output values, with the 95% confidence interval as error bar.

# %% [markdown]
# Parameter plots can now be created by changing the parameter variable in the following code block. The paramater names are listed below.

# %% [markdown]
# - '$p_{uf}$' - The transition probability from unassigned to follower
# - '$p_{pu}$' - The transition probability from pheromoner to unassigned
# - '$p_{up}$' - The transition probability from unassigned to pheromoner
# - '$p_{fl}$' - The transition probability from follower to leader (success)
# - '$p_{lu}$' - The transition probability from leader (and its followers) to unassigned (failure)
# - '$g$' - Group size
# - 'ratio' - Initial ratio leaders, pheromoners
# - '$N$' - Number of ants
# - 'size' - Grid size

# %%
prefix = '../Data/ofat_full2/ofat_3_2_4_'
# Change your param here:
param = 'p_lu'
data = read_data(prefix + param + '.csv')
plot.plot_all_vars(data, param)
plt.show()
